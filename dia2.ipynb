# %% [markdown]
# Ctrl + Shift + P = comando para entrar en modo desarrollador y poder modificar tu visual
# Ctrl + K + C = volver comentario a un codigo
# Ctrl + K + U = volver codigo a tu comentario

# %%
edad = int(input('Por favor escriba su edad'))

if edad >= 18 and edad < 21:
    print('Podes tomar pero no comprar')
elif edad < 18:
    print('Juguito nomas')
else:
    print('Hace lo que quieras')
# Out:
# Podes tomar pero no comprar

# %%
temperatura = float(input('Cuantos grados hace en tu aula?'))
print(f'La temperatura es {temperatura}')

if temperatura >=-10 and temperatura <19:
    print('Fresquete')
elif temperatura >=19 and temperatura <31:
    print("Calor'i")
elif temperatura >=31 and temperatura <46:
    print('Hakuuuuu')
else:
    print("Ñamano mba'e!")
# Out:
# La temperatura es 15.2
# Fresquete

# %%
numero_a_adivinar = 20
numero_ingresado = 0
while numero_ingresado != numero_a_adivinar:
    numero_ingresado = int(input('Ingresa un numero'))
    print(numero_ingresado)
# Out:
# 1
# 2
# 50
# 20

# %%
numero = 10
while True:
    numero_a_ingresar = int(input('Ingresa un numero'))
    if numero_a_ingresar == numero:
        print('El numero es correcto')
        break
    else:
        print('El numero es incorrecto, intentalo de nuevo')
# Out:
# El numero es incorrecto, intentalo de nuevo
# El numero es incorrecto, intentalo de nuevo
# El numero es incorrecto, intentalo de nuevo
# El numero es correcto

# %%
contrasenha_real = 'gatito'
contrasenha = 0

while contrasenha != contrasenha_real:
    contrasenha = input('Por favor ingrese la contraseña')
    print('Contraseña incorrecta')
else:
    print('Desbloqueado master, sos un crack')
# Out:
# Contraseña incorrecta
# Contraseña incorrecta
# Contraseña incorrecta
# Desbloqueado master, sos un crack

# %%
while True:
    contrasenha = input('Coloque la contraseña')
    if contrasenha != contrasenha_real:
        print('Contraseña incorrecta')
    else: 
        print('Pasaste la prueba, adelante')
        break
# Out:
# Contraseña incorrecta
# Contraseña incorrecta
# Contraseña incorrecta
# Contraseña incorrecta
# Pasaste la prueba, adelante

# %%
#                    0      1        2
#elemento(el contenido de la lista) e indice(la posicion de la lista)
lista_de_super = ['chocolate','jugo','leche']
print(lista_de_super)

lista_de_super.append('coca')
print(lista_de_super)

lista_de_super[0] = 'agua'
print(lista_de_super)

lista_de_super.remove('leche')
print(lista_de_super)

lista_de_super.pop(1)
print(lista_de_super)

print(len(lista_de_super))
# Out:
# ['chocolate', 'jugo', 'leche']
# ['chocolate', 'jugo', 'leche', 'coca']
# ['agua', 'jugo', 'leche', 'coca']
# ['agua', 'jugo', 'coca']
# ['agua', 'coca']
# 2

# %%
lista_de_elementos = ['rojo','amarillo','verde','azul','gris']
print(lista_de_elementos)
lista_de_elementos.append('negro')
print(lista_de_elementos)
lista_de_elementos[1] = 'fucsia'
print(lista_de_elementos)
lista_de_elementos.pop(2)
print(lista_de_elementos)
# lista_de_elementos.remove('rojo')
# lista_de_elementos.pop(3)
# lista_de_elementos.append('lila')
# lista_de_elementos[1] = 'marron'
# print(lista_de_elementos)
# Out:
# ['rojo', 'amarillo', 'verde', 'azul', 'gris']
# ['rojo', 'amarillo', 'verde', 'azul', 'gris', 'negro']
# ['rojo', 'fucsia', 'verde', 'azul', 'gris', 'negro']
# ['rojo', 'fucsia', 'azul', 'gris', 'negro']

# %%
for variable in range(10):
    print(f'El numero {variable} por dos es: {variable*2}')
# Out:
# El numero 0 por dos es: 0
# El numero 1 por dos es: 2
# El numero 2 por dos es: 4
# El numero 3 por dos es: 6
# El numero 4 por dos es: 8
# El numero 5 por dos es: 10
# El numero 6 por dos es: 12
# El numero 7 por dos es: 14
# El numero 8 por dos es: 16
# El numero 9 por dos es: 18

# %%
lista_de_marcas = ['puma','nike','adidas','lotto','ositos','channel']
for marcas in lista_de_marcas:
    if len(marcas) >= 6:
        print(marcas)
# Out:
# adidas
# ositos
# channel

# %%
frase = input('Por favor ingrese frase de su agrado')

for let_o in frase:
    if let_o == 'o':
        print('Encontre la letra O')

print('Gracias')
# Out:
# Gracias
